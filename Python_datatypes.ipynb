# %% [markdown]
# <a href="https://colab.research.google.com/github/omkar3103/Python_Core_Practice_codes/blob/main/Python_datatypes.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Python DataTypes

# %%
str = 'My Name is Omkar Manoj Kulkarni'

# %%
age =21
salary = 100

print('current age :',age)
print('current salary :',salary)

print('previous year age :',age-1)
print('salary after 10% increament :',+salary+(salary*10/100))
# Out:
# current age : 21
# current salary : 100
# previous year age : 20
# salary after 10% increament : 110.0

# %%
a=10.34
b=43.12

print("A :",a)
print('B :',b)

print('addition :',a+b)
print(type(a))
print(type(b))
# Out:
# A : 10.34
# B : 43.12
# addition : 53.459999999999994
# <class 'float'>
# <class 'float'>

# %%
is_student = True
is_present = False

print('Student is present in class :',is_student and is_present)
print('Student is went to school :',is_student or is_present)
print('Student is present in class :',not is_present)
# Out:
# Student is present in class : False
# Student is went to school : True
# Student is present in class : True

# %%
#Type Casting :

# %%
a = 21
print(a,type(a))
a = float(a)
print('after type casting :',type(a))
# Out:
# 21 <class 'int'>
# after type casting : <class 'float'>

# %%
is_happy = False
print(type(is_happy))
# Out:
# <class 'bool'>
